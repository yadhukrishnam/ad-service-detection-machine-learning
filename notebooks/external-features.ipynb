# %% [markdown]
# ## External features

# %% [markdown]
# 1. Run webscraper to generate CSV file containting compressed html data. (`html.csv`)
# 2. Merge `html.csv` that contains compressed html data with the current dataset `merged.csv`.
# 3. Move successful requests to `external-feature-dataset.csv`. (Requests which have status codes != 0)
# 4. Retry failed status codes using higher timeout.

# %% [markdown]
# #### Step 1: Run quick webscraper
#
# Save result to html.csv

# %%
! python3 ../webscraper/main.py "../processed-datasets/merged.csv" "../processed-datasets/html.csv" 3

# %%
import pandas as pd

df = pd.read_csv("../processed-datasets/html.csv")

df.head()
# Out:
#    Unnamed: 0                                 url  status_code  \
# 0           0              https://crowdyfan.com/          200
# 1           1             https://dreamaways.com/          403
# 2           2  https://www.worldtravelserver.com/          200
# 3           3             https://www.baarty.com/          200
# 4           4            https://ladamotors63.ru/          200
#
#                                                 html
# 0  b'eNrtfet220bS4G/rHL9Dh5kxpS8CCYB3ymI+WZJtzcS2...
# 1  b'eNqzySjJzbHj5bLJSE1MsbMpySzJSbUzMTBWcMsvSspM...
# 2  b'eNrsvXuX4zaSL/h396fgpI+PK68lFfWWUq7ccdvt7t6e...
# 3  b'eNrtfdtyG0ey4LMVoX8oY+KMpDho3HiXSXgoirY5K1k8...
# 4  b'eNrtPf1zG0WWP1t/RWfudmMdHo0+bMtyLLMkhKvUZoFa...

# %%
html_df = df.drop(["Unnamed: 0"], axis=1)

html_df.head()
# Out:
#                                   url  status_code  \
# 0              https://crowdyfan.com/          200
# 1             https://dreamaways.com/          403
# 2  https://www.worldtravelserver.com/          200
# 3             https://www.baarty.com/          200
# 4            https://ladamotors63.ru/          200
#
#                                                 html
# 0  b'eNrtfet220bS4G/rHL9Dh5kxpS8CCYB3ymI+WZJtzcS2...
# 1  b'eNqzySjJzbHj5bLJSE1MsbMpySzJSbUzMTBWcMsvSspM...
# 2  b'eNrsvXuX4zaSL/h396fgpI+PK68lFfWWUq7ccdvt7t6e...
# 3  b'eNrtfdtyG0ey4LMVoX8oY+KMpDho3HiXSXgoirY5K1k8...
# 4  b'eNrtPf1zG0WWP1t/RWfudmMdHo0+bMtyLLMkhKvUZoFa...

# %% [markdown]
# Join html_df with the domain name dataset

# %%
temp_df = pd.read_csv("../processed-datasets/merged.csv")

df = pd.concat([temp_df, html_df], axis=1, sort=False)

# %%
# df = pd.concat([df, html_df], axis=1, sort=False)

# %%
df.head()
# Out:
#    Unnamed: 0                 domain  class  \
# 0      307713          crowdyfan.com      0
# 1      377353         dreamaways.com      0
# 2      352212  worldtravelserver.com      0
# 3      240236             baarty.com      0
# 4      399659        ladamotors63.ru      0
#
#                                   url  status_code  \
# 0              https://crowdyfan.com/          200
# 1             https://dreamaways.com/          403
# 2  https://www.worldtravelserver.com/          200
# 3             https://www.baarty.com/          200
# 4            https://ladamotors63.ru/          200
#
#                                                 html
# 0  b'eNrtfet220bS4G/rHL9Dh5kxpS8CCYB3ymI+WZJtzcS2...
# 1  b'eNqzySjJzbHj5bLJSE1MsbMpySzJSbUzMTBWcMsvSspM...
# 2  b'eNrsvXuX4zaSL/h396fgpI+PK68lFfWWUq7ccdvt7t6e...
# 3  b'eNrtfdtyG0ey4LMVoX8oY+KMpDho3HiXSXgoirY5K1k8...
# 4  b'eNrtPf1zG0WWP1t/RWfudmMdHo0+bMtyLLMkhKvUZoFa...

# %%
df.groupby("status_code").count()
# Out:
#              Unnamed: 0  domain  class    url   html
# status_code
# 0                 20633   20633  20633  20633      0
# 200               50745   50745  50745  50745  50745
# 201                   4       4      4      4      4
# 202                   2       2      2      2      2
# 203                   2       2      2      2      2
# 204                 362     362    362    362    362
# 301                   1       1      1      1      1
# 302                   2       2      2      2      2
# 400                1006    1006   1006   1006   1006
# 401                 112     112    112    112    112
# 402                  16      16     16     16     16
# 403                6424    6424   6424   6424   6424
# 404                9448    9448   9448   9448   9448
# 405                  18      18     18     18     18
# 406                1244    1244   1244   1244   1244
# 408                   1       1      1      1      1
# 409                  13      13     13     13     13
# 410                  46      46     46     46     46
# 412                  21      21     21     21     21
# 418                   3       3      3      3      3
# 419                   1       1      1      1      1
# 423                   1       1      1      1      1
# 426                   2       2      2      2      2
# 428                   4       4      4      4      4
# 429                 297     297    297    297    297
# 430                   1       1      1      1      1
# 434                   1       1      1      1      1
# 444                  17      17     17     17     17
# 447                  11      11     11     11     11
# 451                  12      12     12     12     12
# 465                   1       1      1      1      1
# 475                   2       2      2      2      2
# 500                 261     261    261    261    261
# 501                   2       2      2      2      2
# 502                  96      96     96     96     96
# 503                1498    1498   1498   1498   1498
# 504                  15      15     15     15     15
# 508                  17      17     17     17     17
# 509                   2       2      2      2      2
# 520                  45      45     45     45     45
# 521                  22      22     22     22     22
# 522                   1       1      1      1      1
# 523                   9       9      9      9      9
# 524                   1       1      1      1      1
# 525                   4       4      4      4      4
# 526                   8       8      8      8      8
# 530                  17      17     17     17     17
# 591                   1       1      1      1      1
# 593                   1       1      1      1      1
# 999                   5       5      5      5      5

# %% [markdown]
# 20k requests failed.

# %% [markdown]
# Write all failed requests into `failed-requests.csv`

# %%
failed_df = df[df['status_code'] == 0].drop(["Unnamed: 0"], axis=1)

failed_df
# Out:
#                              domain  class   url  status_code html
# 16                   vitrinsoft.com      0  fail            0  NaN
# 18              ontrucksolutions.uk      0  fail            0  NaN
# 28                    girlovers.com      0  fail            0  NaN
# 33                     banehnab.com      0  fail            0  NaN
# 42                       zingapp.ir      0  fail            0  NaN
# ...                             ...    ...   ...          ...  ...
# 92452                    yuilop.com      1  fail            0  NaN
# 92453                      yume.com      1  fail            0  NaN
# 92454  zde-affinity.edgecaching.net      1  fail            0  NaN
# 92455                 zeepmedia.com      1  fail            0  NaN
# 92456                   zintext.com      1  fail            0  NaN
#
# [20633 rows x 5 columns]

# %%
failed_df.to_csv("../processed-datasets/failed-requests.csv", index=False)

# %% [markdown]
# Write all successful requests to `external-feature-dataset.csv`

# %%
df.drop(df[df['status_code'] == 0].index, inplace = True)

# %%
df.to_csv("../processed-datasets/external-feature-dataset.csv")

# %% [markdown]
# Re-run scraper on failed URLs

# %%
.head()! python3 ../webscraper/main.py "../processed-datasets/failed-requests.csv" "../processed-datasets/failed-trial-1.csv" 5
# Out:
# Failed: 18260  Total: 20633

# %%
failed_trial_df = pd.read_csv("../processed-datasets/failed-trial-1.csv").drop(["Unnamed: 0"], axis=1)

# %%
failed_trial_df.head()
# Out:
#                            url  status_code  \
# 0  https://www.vitrinsoft.com/          200
# 1                         fail            0
# 2                         fail            0
# 3    https://www.banehnab.com/          200
# 4      https://www.zingapp.ir/          200
#
#                                                 html
# 0  b'eNrtfduS29a14PPRV8BwnVAqN3jvq7o7J46dM66JY5Wt...
# 1                                                NaN
# 2                                                NaN
# 3  b'eNrtfdt220aa7v1ea78Dmpkd26sDEeeDbblHlixbact2...
# 4  b'eNrtfVtzG8eZ6DNTlf8wgS8iKwIIgOANFJmSZDv22fiy...

# %%
failed_trial_df.groupby("status_code").count()
# Out:
#                url  html
# status_code
# 0            18260     0
# 200           1786  1786
# 203              1     1
# 204              1     1
# 400             23    23
# 403            233   233
# 404             21    21
# 406              2     2
# 429            269   269
# 451              1     1
# 500              6     6
# 502              6     6
# 503             16    16
# 504              1     1
# 509              1     1
# 523              6     6

# %% [markdown]
# Merge with failed trial inputs

# %%
temp_df = pd.read_csv("../processed-datasets/failed-requests.csv").drop(["url", "status_code", "html"], axis=1)

# %%
temp_df.head()
# Out:
#                 domain  class
# 0       vitrinsoft.com      0
# 1  ontrucksolutions.uk      0
# 2        girlovers.com      0
# 3         banehnab.com      0
# 4           zingapp.ir      0

# %%
trial_1_df = pd.read_csv("../processed-datasets/failed-trial-1.csv").drop(["Unnamed: 0"], axis=1)

trial_1_df.head()
# Out:
#                            url  status_code  \
# 0  https://www.vitrinsoft.com/          200
# 1                         fail            0
# 2                         fail            0
# 3    https://www.banehnab.com/          200
# 4      https://www.zingapp.ir/          200
#
#                                                 html
# 0  b'eNrtfduS29a14PPRV8BwnVAqN3jvq7o7J46dM66JY5Wt...
# 1                                                NaN
# 2                                                NaN
# 3  b'eNrtfdt220aa7v1ea78Dmpkd26sDEeeDbblHlixbact2...
# 4  b'eNrtfVtzG8eZ6DNTlf8wgS8iKwIIgOANFJmSZDv22fiy...

# %%
trial_1_df = pd.concat([temp_df, trial_1_df], axis=1, sort=False)

# %%
trial_1_df.head()
# Out:
#                 domain  class                          url  status_code  \
# 0       vitrinsoft.com      0  https://www.vitrinsoft.com/          200
# 1  ontrucksolutions.uk      0                         fail            0
# 2        girlovers.com      0                         fail            0
# 3         banehnab.com      0    https://www.banehnab.com/          200
# 4           zingapp.ir      0      https://www.zingapp.ir/          200
#
#                                                 html
# 0  b'eNrtfduS29a14PPRV8BwnVAqN3jvq7o7J46dM66JY5Wt...
# 1                                                NaN
# 2                                                NaN
# 3  b'eNrtfdt220aa7v1ea78Dmpkd26sDEeeDbblHlixbact2...
# 4  b'eNrtfVtzG8eZ6DNTlf8wgS8iKwIIgOANFJmSZDv22fiy...

# %% [markdown]
# Export all valid statuscodes to external-feature-dataset

# %%
trial_1_df[trial_1_df['status_code'] != 0].to_csv('../processed-datasets/external-feature-dataset.csv', mode='a', header=False)

# %%
import pandas as pd

# %%
pd.read_csv("../processed-datasets/external-feature-dataset.csv").drop(["Unnamed: 0"], axis=1).groupby("class").count()
# Out:
#        domain    url  status_code   html
# class
# 0       43609  43609        43609  43609
# 1       30589  30589        30589  30589
